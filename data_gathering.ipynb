# %% [markdown]
# ##### Installing git in python

# %%
# pip install gitpython

# %% [markdown]
# ##### Cloning repo

# %%
# from git import Repo

# repo_url = "https://github.com/PhonePe/pulse.git"
# destination = r"C:\Phonpay Transaction Insights\data"

# # Correct method
# Repo.clone_from(repo_url, destination)

# %%
import os
path = "./data/aggregated/transaction/country/india/state/"
agg_state_list = os.listdir(path)
agg_state_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
import pandas as pd
import json

clm = {'id':[], 'state':[],'year':[],'quater':[],'transaction_type':[], 'transaction_count': [], 'transaction_amount':[]}
id = 1
for i in agg_state_list:
    p_i = path+i+"/"
    agg_yr = os.listdir(p_i)
    for j in agg_yr:
        p_j = p_i + j + "/"
        agg_yr_list = os.listdir(p_j)
        for k in agg_yr_list:
            p_k = p_j + k
            data = open(p_k, 'r')
            d = json.load(data)
            for z in d['data']['transactionData']:
                name = z['name']
                count = z['paymentInstruments'][0]['count']
                amount = z['paymentInstruments'][0]['amount']
                clm['transaction_type'].append(name)
                clm['transaction_count'].append(count)
                clm['transaction_amount'].append(amount)
                clm['state'].append(i)
                clm['year'].append(j)
                clm['quater'].append(int(k.strip('.json')))
                clm['id'].append(id)
                id = id +1

Agg_Trans = pd.DataFrame(clm)

# %%
Agg_Trans
# Out:
#         id                      state  year  quater          transaction_type  \
# 0        1  andaman-&-nicobar-islands  2018       1  Recharge & bill payments
# 1        2  andaman-&-nicobar-islands  2018       1     Peer-to-peer payments
# 2        3  andaman-&-nicobar-islands  2018       1         Merchant payments
# 3        4  andaman-&-nicobar-islands  2018       1        Financial Services
# 4        5  andaman-&-nicobar-islands  2018       1                    Others
# ...    ...                        ...   ...     ...                       ...
# 5029  5030                west-bengal  2024       4         Merchant payments
# 5030  5031                west-bengal  2024       4     Peer-to-peer payments
# 5031  5032                west-bengal  2024       4  Recharge & bill payments
# 5032  5033                west-bengal  2024       4        Financial Services
# 5033  5034                west-bengal  2024       4                    Others
#
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+mysqlconnector://root:root@localhost:3306/phonepe_insights')
Agg_Trans.to_sql(name='aggregated_transactions_stats', con=engine, if_exists='replace', index=False)
engine.dispose()

# %% [markdown]
# ### Map Transaction

# %%
import os
path = "./data/map/transaction/hover/country/india/state/"
agg_state_list = os.listdir(path)
agg_state_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
import pandas as pd
import json

clm = {'id':[], 'state':[], 'district':[], 'year':[],'quarter':[],'transaction_count': [], 'transaction_amount':[]}
id = 1
for i in agg_state_list:
    p_i = path+i+"/"
    agg_yr = os.listdir(p_i)
    for j in agg_yr:
        p_j = p_i + j + "/"
        agg_yr_list = os.listdir(p_j)
        for k in agg_yr_list:
            p_k = p_j + k
            data = open(p_k, 'r')
            d = json.load(data)
            for z in d['data']['hoverDataList']:
                name = z['name']
                count = z['metric'][0]['count']
                amount = z['metric'][0]['amount']
                clm['district'].append(name)
                clm['transaction_count'].append(count)
                clm['transaction_amount'].append(amount)
                clm['state'].append(i)
                clm['year'].append(j)
                clm['quarter'].append(int(k.strip('.json')))
                clm['id'].append(id)
                id = id +1

Agg_Trans = pd.DataFrame(clm)

# %%
Agg_Trans
# Out:
#           id                      state                           district  \
# 0          1  andaman-&-nicobar-islands  north and middle andaman district
# 1          2  andaman-&-nicobar-islands             south andaman district
# 2          3  andaman-&-nicobar-islands                  nicobars district
# 3          4  andaman-&-nicobar-islands  north and middle andaman district
# 4          5  andaman-&-nicobar-islands             south andaman district
# ...      ...                        ...                                ...
# 20599  20600                west-bengal                alipurduar district
# 20600  20601                west-bengal         paschim bardhaman district
# 20601  20602                west-bengal                     nadia district
# 20602  20603                west-bengal                   birbhum district
# 20603  20604                west-bengal           purba medinipur district
#
#        year  quarter  transaction_count  transaction_amount
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+mysqlconnector://root:root@localhost:3306/phonepe_insights')
Agg_Trans.to_sql(name='mapped_transaction_district_totals', con=engine, if_exists='replace', index=False)
engine.dispose()

# %% [markdown]
# #### map user

# %%
import os
path = "./data/map/user/hover/country/india/state/"
agg_state_list = os.listdir(path)
agg_state_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
import pandas as pd
import json

clm = {'id':[], 'state':[], 'district':[], 'year':[], 'registered_users': [], 'app_opens':[], 'quarter':[]}
id = 1
for i in agg_state_list:
    p_i = path+i+"/"
    agg_yr = os.listdir(p_i)
    for j in agg_yr:
        p_j = p_i + j + "/"
        agg_yr_list = os.listdir(p_j)
        for k in agg_yr_list:
            p_k = p_j + k
            data = open(p_k, 'r')
            d = json.load(data)
            hover_data = d["data"]["hoverData"]
            for district, values in hover_data.items():
                registeredUsers = values['registeredUsers']
                appOpens = values['appOpens']
                clm['district'].append(district)
                clm['registered_users'].append(registeredUsers)
                clm['app_opens'].append(appOpens)
                clm['state'].append(i)
                clm['year'].append(j)
                clm['quarter'].append(int(k.strip('.json')))
                clm['id'].append(id)
                id = id +1

Agg_Trans = pd.DataFrame(clm)

# %%
Agg_Trans
# Out:
#           id                      state                           district  \
# 0          1  andaman-&-nicobar-islands  north and middle andaman district
# 1          2  andaman-&-nicobar-islands             south andaman district
# 2          3  andaman-&-nicobar-islands                  nicobars district
# 3          4  andaman-&-nicobar-islands  north and middle andaman district
# 4          5  andaman-&-nicobar-islands             south andaman district
# ...      ...                        ...                                ...
# 20603  20604                west-bengal                alipurduar district
# 20604  20605                west-bengal         paschim bardhaman district
# 20605  20606                west-bengal                     nadia district
# 20606  20607                west-bengal                   birbhum district
# 20607  20608                west-bengal           purba medinipur district
#
#        year  registered_users  app_opens  quarter
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+mysqlconnector://root:root@localhost:3306/phonepe_insights')
Agg_Trans.to_sql(name='mapped_user_devise_district', con=engine, if_exists='replace', index=False)
engine.dispose()

# %% [markdown]
# #### Aggregated Insurance

# %%
import os
path = "./data/aggregated/insurance/country/india/state/"
agg_state_list = os.listdir(path)
agg_state_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
import pandas as pd
import json

clm = {'id':[],'state':[],'year':[],'quater':[],'insurance_type':[], 'insurance_count': [], 'insurance_amount':[]}
id = 1
for i in agg_state_list:
    p_i = path+i+"/"
    agg_yr = os.listdir(p_i)
    for j in agg_yr:
        p_j = p_i + j + "/"
        agg_yr_list = os.listdir(p_j)
        for k in agg_yr_list:
            p_k = p_j + k
            data = open(p_k, 'r')
            d = json.load(data)
            for z in d['data']['transactionData']:
                name = z['name']
                count = z['paymentInstruments'][0]['count']
                amount = z['paymentInstruments'][0]['amount']
                clm['insurance_type'].append(name)
                clm['insurance_count'].append(count)
                clm['insurance_amount'].append(amount)
                clm['state'].append(i)
                clm['year'].append(j)
                clm['quater'].append(int(k.strip('.json')))
                clm['id'].append(id)
                id = id +1


Agg_Trans = pd.DataFrame(clm)

# %%
Agg_Trans
# Out:
#       id                      state  year  quater insurance_type  \
# 0      1  andaman-&-nicobar-islands  2020       2      Insurance
# 1      2  andaman-&-nicobar-islands  2020       3      Insurance
# 2      3  andaman-&-nicobar-islands  2020       4      Insurance
# 3      4  andaman-&-nicobar-islands  2021       1      Insurance
# 4      5  andaman-&-nicobar-islands  2021       2      Insurance
# ..   ...                        ...   ...     ...            ...
# 677  678                west-bengal  2023       4      Insurance
# 678  679                west-bengal  2024       1      Insurance
# 679  680                west-bengal  2024       2      Insurance
# 680  681                west-bengal  2024       3      Insurance
# 681  682                west-bengal  2024       4      Insurance
#
#      insurance_count  insurance_amount
# 0                  6            1360.0
# 1                 41           15380.0
# 2                124          157975.0
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+mysqlconnector://root:root@localhost:3306/phonepe_insights')
Agg_Trans.to_sql(name='aggregated_insurance_stats', con=engine, if_exists='replace', index=False)
engine.dispose()

# %% [markdown]
# ## Aggregated User

# %%
import os
path = "./data/aggregated/user/country/india/state/"
agg_state_list = os.listdir(path)
agg_state_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
import pandas as pd
import json

clm = {'id':[], 'state':[],'year':[],'quarter':[],'user_brand':[], 'user_count': [], 'user_percentage':[]}
id = 1
for i in agg_state_list:
    p_i = path+i+"/"
    agg_yr = os.listdir(p_i)
    for j in agg_yr:
        p_j = p_i + j + "/"
        agg_yr_list = os.listdir(p_j)
        for k in agg_yr_list:
            p_k = p_j + k
            data = open(p_k, 'r')
            d = json.load(data)
            if d['data']['usersByDevice'] is not None:
                for z in d['data']['usersByDevice']:
                    name = z['brand']
                    count = z['count']
                    amount = z['percentage']
                    clm['user_brand'].append(name)
                    clm['user_count'].append(count)
                    clm['user_percentage'].append(amount)
                    clm['state'].append(i)
                    clm['year'].append(j)
                    clm['quarter'].append(int(k.strip('.json')))
                    clm['id'].append(id)
                    id = id +1


Agg_Trans = pd.DataFrame(clm)

# %%
Agg_Trans
# Out:
#         id                      state  year  quarter user_brand  user_count  \
# 0        1  andaman-&-nicobar-islands  2018        1     Xiaomi        1665
# 1        2  andaman-&-nicobar-islands  2018        1    Samsung        1445
# 2        3  andaman-&-nicobar-islands  2018        1       Vivo         982
# 3        4  andaman-&-nicobar-islands  2018        1       Oppo         501
# 4        5  andaman-&-nicobar-islands  2018        1    OnePlus         332
# ...    ...                        ...   ...      ...        ...         ...
# 6727  6728                west-bengal  2022        1     Lenovo      330017
# 6728  6729                west-bengal  2022        1    Infinix      284678
# 6729  6730                west-bengal  2022        1       Asus      280347
# 6730  6731                west-bengal  2022        1      Apple      277752
# 6731  6732                west-bengal  2022        1     Others     2196334
#
#       user_percentage
# 0            0.247033
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+mysqlconnector://root:root@localhost:3306/phonepe_insights')
Agg_Trans.to_sql(name='aggregated_user_device_stats', con=engine, if_exists='replace', index=False)
# Out:
# 6732

# %% [markdown]
# ## Aggregated User

# %%
import os
import json
import pandas as pd

# agg_state_list should be a list of pulse-style state keys, e.g.:
# agg_state_list = ['maharashtra', 'andhra-pradesh', ...]
# base_dir should point to: .../data/aggregated/user/country/india/state
# final JSON paths: base_dir/<state>/<year>/<quarter>.json

base_dir = "./data/aggregated/user/country/india/state/"

rows = []
id_counter = 1

for state in agg_state_list:
    state_dir = os.path.join(base_dir, state)
    if not os.path.isdir(state_dir):
        continue

    for year in os.listdir(state_dir):
        year_dir = os.path.join(state_dir, year)
        if not os.path.isdir(year_dir):
            continue

        for qfile in os.listdir(year_dir):
            if not qfile.endswith(".json"):
                continue

            q = int(qfile.replace(".json", ""))   # quarter as int
            fpath = os.path.join(year_dir, qfile)

            try:
                with open(fpath, "r", encoding="utf-8") as f:
                    d = json.load(f)

                agg = d.get("data", {}).get("aggregated", {})
                # Guard against missing keys
                registered_users = int(agg.get("registeredUsers", 0) or 0)
                app_opens = int(agg.get("appOpens", 0) or 0)

                rows.append({
                    "id": id_counter,
                    "state": state,           # keep raw pulse key; pretty-map in UI
                    "year": int(year),
                    "quarter": q,
                    "total_users": registered_users,
                    "app_opens": app_opens
                })
                id_counter += 1

            except Exception as e:
                # Optional: collect bad paths for later inspection
                print(f"[WARN] Failed to parse {fpath}: {e}")

Agg_State = pd.DataFrame(rows, columns=["id","state","year","quarter","total_users","app_opens"])

# %%
Agg_State
# Out:
#         id                      state  year  quarter  total_users   app_opens
# 0        1  andaman-&-nicobar-islands  2018        1         6740           0
# 1        2  andaman-&-nicobar-islands  2018        2         9405           0
# 2        3  andaman-&-nicobar-islands  2018        3        12149           0
# 3        4  andaman-&-nicobar-islands  2018        4        15222           0
# 4        5  andaman-&-nicobar-islands  2019        1        18596           0
# ...    ...                        ...   ...      ...          ...         ...
# 1003  1004                west-bengal  2023        4     30064546  1467442959
# 1004  1005                west-bengal  2024        1     31306843   633526507
# 1005  1006                west-bengal  2024        2     32540397   704276274
# 1006  1007                west-bengal  2024        3     33612828   709864323
# 1007  1008                west-bengal  2024        4     34750181  1994940763
#
# [1008 rows x 6 columns]

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+mysqlconnector://root:root@localhost:3306/phonepe_insights')
Agg_State.to_sql(name='aggregated_user_state_totals', con=engine, if_exists='replace', index=False)
# Out:
# 1008

# %%
# --- setup: imports & DB engine ---
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine, text

# nice defaults
sns.set_theme(context="notebook", style="whitegrid")

# MySQL connection (adjust user/pass/host/db)
ENGINE = create_engine('mysql+mysqlconnector://root:root@localhost:3306/phonepe_insights')

def q(sql, **params) -> pd.DataFrame:
    with ENGINE.connect() as conn:
        return pd.read_sql(text(sql), conn, params=params)
